# %% [markdown]
# # ETL Python SQLite
#
# Load the synthetic operations CSV and preview transformations.

# %%
from pathlib import Path
    import pandas as pd

    data_path = Path("..") / "data" / "sample_synthetic_data.csv"
    df = pd.read_csv(data_path)
    display(df.head())
    display(df.describe(include="all").transpose().head(12))
    display(df.groupby(["region", "channel"])["contacts"].sum().reset_index().head())
